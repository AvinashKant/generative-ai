# %%
import pandas as pd

df = pd.read_csv("../sampledata/sales_data_sample.csv", encoding='latin-1')

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df['ORDERNUMBER']
# Out:
# 0       10107
# 1       10121
# 2       10134
# 3       10145
# 4       10159
#         ...
# 2818    10350
# 2819    10373
# 2820    10386
# 2821    10397
# 2822    10414
# Name: ORDERNUMBER, Length: 2823, dtype: int64

# %%
df[['ORDERNUMBER','STATUS']]
# Out:
#       ORDERNUMBER    STATUS
# 0           10107   Shipped
# 1           10121   Shipped
# 2           10134   Shipped
# 3           10145   Shipped
# 4           10159   Shipped
# ...           ...       ...
# 2818        10350   Shipped
# 2819        10373   Shipped
# 2820        10386  Resolved
# 2821        10397   Shipped
# 2822        10414   On Hold
#
# [2823 rows x 2 columns]

# %%
df[(df['STATUS']=='Shipped') & (df['YEAR_ID']==2003)]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2800        10142               39      44.23                5  1724.97
# 2801        10153               50      60.06                4  3003.00
# 2803        10177               40      50.23                6  2009.20
# 2804        10185               28      64.43                6  1804.04
# 2805        10197               42      50.23               12  2109.66
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...
