# %%
import pandas as pd

df = pd.read_json("../sampledata/sample_Data.json", encoding='latin-1')

df
# Out:
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# 7    8                 Dyson V11 Absolute Cordless Vacuum
# 8    9                         Ninja Foodi Smart XL Grill
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 12  13                    Fitbit Charge 4 Fitness Tracker
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
# ...

# %%
df.shape
# Out:
# (20, 6)

# %%
df['new_price'] = df['price']*2

# %%
df[['price','new_price']]
# Out:
#       price  new_price
# 0    999.00    1998.00
# 1    799.00    1598.00
# 2    499.99     999.98
# 3   1599.99    3199.98
# 4    299.00     598.00
# 5    229.95     459.90
# 6    399.99     799.98
# 7    699.99    1399.98
# 8    279.99     559.98
# 9    899.00    1798.00
# 10   249.00     498.00
# 11   299.00     598.00
# 12   129.95     259.90
# 13   399.99     799.98
# 14   349.99     699.98
# 15   699.95    1399.90
# 16   169.99     339.98
# 17   799.99    1599.98
# 18   209.99     419.98
# 19   139.99     279.98

# %% [markdown]
# # using insert
# df.insert(location,'column',data)

# %%
df.insert(4,'new_price_1',df['price']*2)

# %%
df
# Out:
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# 7    8                 Dyson V11 Absolute Cordless Vacuum
# 8    9                         Ninja Foodi Smart XL Grill
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 12  13                    Fitbit Charge 4 Fitness Tracker
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
# ...

# %% [markdown]
# df.loc[row_index,'column name'] = value

# %%
df.loc[0,'name'] = 'Apple iPhone 13'
df
# Out:
#     id                                               name  \
# 0    1                                    Apple iPhone 13
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# 7    8                 Dyson V11 Absolute Cordless Vacuum
# 8    9                         Ninja Foodi Smart XL Grill
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 12  13                    Fitbit Charge 4 Fitness Tracker
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'description', 'price', 'new_price_1', 'category',
#        'image', 'new_price'],
#       dtype='str')

# %%
df.drop(columns=["new_price_1"],inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'name', 'description', 'price', 'category', 'image', 'new_price'], dtype='str')
